# %% [markdown]
# <a href="https://colab.research.google.com/github/cybercrypto-hash/Cloud-Project-Management-Internship/blob/master/Neural_Networks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Project Number One 

# Make a neural net- July 2. 2022

# Finished intital neural network. Now we can use this to make predictions. 

# Finished first half at 4:40 pm. July 2, 2022. 


""" Use this neural network to predict a logistic regression problems chances of 
making an accurate prediction. """

# import the relevant libraries. 

import numpy, random, os

# Set the learning rate (lr)

lr= 1

# Set the bias

bias = 1

# Set the weights. 

# Here, we've randomized our weights.

weights = [random.random(), random.random(), random.random() ]

# Weights were generated in a list- 3 in total. 2 neurons and one bias. 



def Perceptrons(input1, input2, output):

  output_x = input1 * weights[0] + input2 * weights[1] + bias * weights[2]
  
  if output_x > 0: 
    output_x = 1
  else: 
    output_x = 0

    # Error defined
    error = output - output_x

    # Initialize the weights and give them some values. 

    weights[0] += error * input1 * lr 
    weights[1] += error * input2 * lr  
    weights[2] += error * bias * lr 

# Made a function which tells us the output of our neurons. 

for i in range(50): 
  Perceptrons(1,1,1)
  Perceptrons(1,0,1)
  Perceptrons(0,1,1)
  Perceptrons(0,0,0)


x = int(input())
y = int(input())
output_x = x * weights[0] + y*weights[1] + bias * weights[2]
"""if output_x > 0: 
  output_x = 1 
else: 
  output_x = 0 
print(x, "or", y, "is :", output_x)
"""
# We can use a sigmoid function for the activation function(fx). 
      
output_x = 1/(1+numpy.exp(-output_x))


# Make a logistic regression model and then combine it with the above. 

# Import the relevant libraries for part 2 

import csv, pandas as pd, matplotlib.pyplot as plt
from sklearn import preprocessing
plt.rc("font", size = 14)
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split
import seaborn as sns
sns.set(style="white")
sns.set(style="whitegrid", color_codes=True)
from sklearn import metrics

# Import dataset; in this case, I used a built-in one from sklearn. 


# Dataset read via iteration and import csv. 

"""with open('california_housing_test.csv', newline = '') as f :
  read_In = csv.reader(f)
  for row in read_In: 
    print(row)
"""

# Dataset read via pandas.pd format for csv (excel files.)


d_Read = pd.read_csv('california_housing_test.csv', index_col = 0)

# Show dataframe in order to easily read what we are working with now. 

print(d_Read)

# Preprocessing Steps taken here:


# Decide what your x values are and what your y values are. 


# Then decide what is your testing values and your training values will be. 

# We will be predicting the housing price based on income. 

# Dependent vs independent variables. 

dependent_1 = " housing prices "
independent_1_ = "median income"

# X is our dependent varaible and Y is our independent variable. 

# Now, we can go ahead and create our logistic regression formula. 
X = d_Read[['median_income', 'housing_median_age']]
Y = d_Read[['median_house_value']]

# Created our testing and training data. 

""" Here we are using half of the date for our testing data and half for our
 training data.""" 

X_train, X_test, Y_train, Y_test = train_test_split(X,Y, test_size= 0.2, random_state=0 )

# Logistic Regression Applied below: 

logistic_regression = LogisticRegression()
logistic_regression.fit(X_train,Y_train)
Predicted_Y_Value = logistic_regression.predict(X_test)

"""
Implemented a confusion matric- tells us how well our classification algorithm 
will work. """

"""confusion_matrix = pd.crosstab(Y_test, Predicted_Y_Value, rownames=['median_income', 'housing_median_age'], colnames=['median_house_value'])
sn.heatmap(confusion_matrix, annot=True)
"""

print('Accuracy: ',metrics.accuracy_score(Y_test, Predicted_Y_Value))
plt.show()
# Out:
# 56
# 78
#            latitude  housing_median_age  total_rooms  total_bedrooms  \
# longitude
# -122.05       37.37                27.0       3885.0           661.0
# -118.30       34.26                43.0       1510.0           310.0
# -117.81       33.78                27.0       3589.0           507.0
# -118.36       33.82                28.0         67.0            15.0
# -119.67       36.33                19.0       1241.0           244.0
# ...             ...                 ...          ...             ...
# -119.86       34.42                23.0       1450.0           642.0
# -118.14       34.06                27.0       5257.0          1082.0
# -119.70       36.30                10.0        956.0           201.0
# -117.12       34.10                40.0         96.0            14.0
# -119.63       34.42                42.0       1765.0           263.0
#
#            population  households  median_income  median_house_value
# longitude
# ...

# %%
# July 2, 2022 Make a Recurrent Neural Network (RNN) with Keras. 

# Began project July 3, 2022


# Imported relevant libraries: 

import numpy as np 
import tensorflow as tf
from tensorflow import keras
from tensorflow. keras import layers


number_inputs = 100
number_neurons = 150 
n_steps = 25

model = keras.Sequential()

# Input size of a 1000 and output embedding dim. size 2000. 
model.add(layers.Embedding(input_dim=1000, output_dim= 2000))

# Add your layers 

# LSTM layer and Dense layer
model.add(layers.LSTM(128))

model.add(layers.Dense(2))

# Outputs of GRY and Simple RNN


# The output of SimpleRNN will be a 2D tensor of shape (batch_size, 128)


# Summary of model 
model.summary()
X_batch = np.array([
        [[0, 1, 2, 5], [9, 8, 7, 4]], 
        [[3, 4, 5, 2], [0, 0, 0, 0]],
        [[6, 7, 8, 5], [6, 5, 4, 2]],
    ])


# Done for now.
# Out:
# Model: "sequential_16"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  embedding_15 (Embedding)    (None, None, 2000)        2000000
#
#  lstm_14 (LSTM)              (None, 128)               1090048
#
#  dense_12 (Dense)            (None, 2)                 258
#
# ...
# Total params: 3,090,306
# Trainable params: 3,090,306
# Non-trainable params: 0
# _________________________________________________________________
